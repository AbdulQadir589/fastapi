# %%
import os
import time
import subprocess
import fnmatch
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
food = pd.read_csv('food.csv')
food.head()
# Out:
#              Food_items  Breakfast  Lunch  Dinner VegNovVeg  Calories  Fats  \
# 0      Asparagus Cooked          0      1       1                  22   0.2
# 1              Avocados          1      0       0         0       160  15.0
# 2               Bananas          1      0       0         0        89   0.3
# 3  Bagels made in wheat          0      1       1         0       250   1.5
# 4               Berries          1      0       0         0       349   0.4
#
#    Proteins  Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  \
# 0       2.4  0.91     23.0      14      224.0            4.1    2.0         0
# 1       2.0  0.55     12.0       7      485.0            8.5    6.7         0
# 2       1.1  0.26      5.0       1      358.0           23.0    2.6         0
# 3      10.0  2.76     20.0     439      165.0           49.0    4.1         0
# 4      14.0  6.80    190.0     298       77.0           77.0   13.0         0
#
#    Sugars
# 0     1.3
# 1     0.7
# 2    12.0
# 3     6.1
# 4    46.0

# %%
nut_dis = pd.read_csv('nutrition_distriution.csv')
nut_dis.head()
# Out:
#    0Calories   1Fats (gm)  2Proteins(g)  3Iron(mg)  4Calcium(mg)  5Sodium(mg)  \
# 0         160        15.0           2.0       0.55            12            7
# 1          89         0.3           1.1       0.26             5            1
# 2         349         0.4          14.0       6.80           190          298
# 3         331        24.0          20.0       0.84           497          966
# 4           2         0.0           0.3       0.02             2            1
#
#    6Potassium(mg)  7Carbohydrates (gm)  8Fibre (gm)  9Vitamin D (mcg)  \
# 0           485.0                  8.5          6.7                 0
# 1           358.0                  8.5          2.6                 0
# 2            77.0                  8.5         13.0                 0
# 3           363.0                  8.5          0.0                 0
# 4            50.0                  8.5          0.0                 0
#
#    10Sugars (gm)
# 0            0.7
# 1           12.0
# 2           46.0
# 3            0.0
# 4            0.0

# %%
food.Fats.iloc[0]
# Out:
# 0.2

# %%
food.Calories.mean()
